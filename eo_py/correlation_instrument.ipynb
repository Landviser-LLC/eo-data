# %% [markdown]
# ## Quick correlation

# %%
# import needed modules
# %pylab inline
import pandas as pd
import seaborn as sns
import os
# usefull to see and scroll through bigger dframes
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
print("Current Working Directory " , os.getcwd())
# Out:
# Current Working Directory  D:\VC_LG\Smart-Rice\py

# %%
path = 'D:/VC_LG/Smart-Rice/data_in/AEMP/'
lst_csv = os.listdir(path)
lst_csv
#df_aemp = pd.read_csv(path)
# Out:
# ['data_AEMP14-Rostov-49_2.csv', 'data_AEMP14-Rostov-49_eng.csv']

# %%
file = path + lst_csv[1]
import chardet
with open(file, 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
result
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.4879473684210526, 'language': ''}

# %%
df_aemp = pd.read_csv(path + lst_csv[0], encoding='windows-1251')
df_aemp.dropna(axis=1, how='all', inplace=True)
df_aemp.dropna(axis=0, how='all', inplace=True)
df_aemp
# Out:
#    Номер точки  0-30_Содержание гумуса, %  0-10_рН  10-20_рН  20-30_рН  \
# 0          1.0                       3.02     7.58      7.78      8.29
# 1          2.0                       3.21     8.06      8.12      8.20
# 2          3.0                       2.81     8.26      8.34      8.09
# 3          4.0                       3.00     7.46      8.07      7.90
# 4          5.0                       3.21     7.94      8.13      7.96
# 5          6.0                       3.11     7.98      8.06      8.02
# 6          7.0                       3.30     7.55      7.81      7.86
# 7          8.0                       3.10     8.05      8.00      8.08
#
#    ABS e.m.f. F8  ABS e.m.f. F9  ABS e.m.f. F10  ABS e.m.f. F11  \
# 0      29.876623      32.076072       35.722938       40.973959
# 1      30.702558      32.693290       36.040952       41.055786
# 2      26.122176      28.186239       30.530830       34.094851
# 3      25.296788      27.196456       29.984883       34.017641
# ...

# %%
df_aemp.describe(include='all').T.round(3)
# Out:
#                                               count    mean     std     min  \
# Номер точки                                     8.0   4.500   2.449   1.000
# 0-30_Содержание гумуса, %                       8.0   3.095   0.153   2.810
# 0-10_рН                                         8.0   7.860   0.291   7.460
# 10-20_рН                                        8.0   8.039   0.180   7.780
# 20-30_рН                                        8.0   8.050   0.146   7.860
# ABS e.m.f. F8                                   8.0  26.315   3.449  21.277
# ABS e.m.f. F9                                   8.0  28.117   3.699  22.628
# ABS e.m.f. F10                                  8.0  30.743   4.320  25.054
# ABS e.m.f. F11                                  8.0  34.483   5.354  27.789
# ABS e.m.f. F12                                  8.0  41.525   7.605  32.576
# ABS e.m.f. F13                                  8.0  54.129  11.007  41.151
# ...

# %%
df_aemp.columns
# Out:
# Index(['Номер точки', '0-30_Содержание гумуса, %', '0-10_рН', '10-20_рН',
#        '20-30_рН', 'ABS e.m.f. F8', 'ABS e.m.f. F9', 'ABS e.m.f. F10',
#        'ABS e.m.f. F11', 'ABS e.m.f. F12', 'ABS e.m.f. F13', 'ABS e.m.f. F14',
#        '0-10_Влаж (%)', '10-20 _Влаж (%)', '20-30_Влаж (%)', '30-40_Влаж (%)',
#        '40-50_Влаж (%)', '50-60_Влаж (%)', '60-70_Влаж (%)', '70-80_Влаж (%)',
#        '80-90_Влаж (%)', '90-100_Влаж (%)',
#        'Запас продуктивной влаги в слое 0-20 см, мм',
#        'Запас продуктивной влаги в слое 0-100 см, мм', 'lat', 'long'],
#       dtype='object')

# %%
corr = df_aemp.corr()
plt.figure(figsize=(20,8))
sns.heatmap(corr, cmap="Greens",annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Separating Sensor and Soil Properties Data Frames

# %%
emf_col = ['ABS e.m.f. F8', 'ABS e.m.f. F9', 'ABS e.m.f. F10', 'ABS e.m.f. F11',
       'ABS e.m.f. F12', 'ABS e.m.f. F13', 'ABS e.m.f. F14']
soil_col = ['humus_0-30cm', '0-10_рН', '10-20_рН', '20-30_рН', '0-10_WC%',
       '10-20_WC%', '20-30_WC%', '30-40_WC%', '40-50_WC%', '50-60_WC%',
       '60-70_WC%', '70-80_WC%', '80-90_WC%', '90-100_WC%',
       'Available_Water_ 0-20cm_mm', 'Available_Water_ 0-1m_mm']

# %%
df_emf = pd.DataFrame(df_aemp, columns=emf_col)
df_soil = pd.DataFrame(df_aemp, columns=soil_col)

# %% [markdown]
# ## Correlating DFrame to DFrame

# %%
df_emf.corrwith(df_soil, axis = 1)
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# dtype: float64

# %%
#corr = df_aemp.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);
